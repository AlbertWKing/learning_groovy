# %% [markdown]
# Uses Conda env AKStandard Py 3.11.9

# %%
import time
import datetime

start = datetime.datetime.now()

for x in range(3):
    print(f'Hello {x}')

end = datetime.datetime.now()

print((end-start)*1000)
# Out:
# Hello 0
# Hello 1
# Hello 2
# 0:00:00.065000

# %%
times = []

for run in range(1000000):

    start = time.perf_counter()

    for x in range(3):
        # print(f'Hello {x}')
        pass

    end = time.perf_counter()

    loop_time = end-start

    times.append(loop_time*10E6)

print(sum(times)/len(times))
# Out:
# 1.6993727575754747

# %%
start = time.perf_counter()

for x in range(3):
    # print(f'Hello {x}')
    pass

end = time.perf_counter()

loop_time = end-start

print(loop_time*10E6)
# Out:
# 550.4098953679204

# %%
start = datetime.datetime.now()

for x in range(3):
    print(f'Hello {x}')

time.sleep(2)

end = datetime.datetime.now()

print(end-start)
# Out:
# Hello 0
# Hello 1
# Hello 2
# 0:00:02.006411
